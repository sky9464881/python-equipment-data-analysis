# %%
import pandas as pd

# %%
# 데이터 불러오기

# %%
pd.read_csv("./data/01_equipment.csv")
# Out:
#   equipment_id equipment_name equipment_type location  rated_capacity  \
# 0      INJ-001        사출기 1호기            사출기   A동 1라인           150.0
# 1      INJ-002        사출기 2호기            사출기   A동 1라인           150.0
# 2    PRESS-001        프레스 1호기            프레스   A동 2라인           200.0
# 3    PRESS-002        프레스 2호기            프레스   A동 2라인           200.0
# 4      ASM-001       조립라인 1호기           조립라인   B동 1라인           100.0
#
#   installation_date  status           created_at           updated_at
# 0        2020-03-15  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00
# 1        2021-06-20  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00
# 2        2019-05-10  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00
# 3        2022-08-25  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00
# 4        2020-11-30  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00

# %%
df=pd.read_csv("./data/01_equipment.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   equipment_id       5 non-null      object
#  1   equipment_name     5 non-null      object
#  2   equipment_type     5 non-null      object
#  3   location           5 non-null      object
#  4   rated_capacity     5 non-null      float64
#  5   installation_date  5 non-null      object
#  6   status             5 non-null      object
#  7   created_at         5 non-null      object
#  8   updated_at         5 non-null      object
# dtypes: float64(1), object(8)
# memory usage: 488.0+ bytes

# %%
df_production=pd.read_csv('./data/05_production.csv')

# %%
df_production
# Out:
#       production_id equipment_id product_code production_date  \
# 0                 1      INJ-001     BUMPER-A      2024-01-01
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 2                 3      INJ-002     BUMPER-A      2024-01-01
# 3                 4      INJ-002       DASH-C      2024-01-01
# 4                 5      INJ-002       DOOR-B      2024-01-01
# ...             ...          ...          ...             ...
# 1867           1868    PRESS-002     BUMPER-A      2024-03-31
# 1868           1869    PRESS-002       DASH-C      2024-03-31
# 1869           1870    PRESS-002     BUMPER-A      2024-03-31
# 1870           1871      ASM-001     BUMPER-A      2024-03-31
# 1871           1872      ASM-001       DOOR-B      2024-03-31
#
#                start_time             end_time  target_quantity  \
# 0     2024-01-01 08:14:00  2024-01-01 09:53:32               97
# 1     2024-01-01 21:02:00  2024-01-01 22:33:43               83
# ...

# %%
df.head(2)
# Out:
#   equipment_id equipment_name equipment_type location  rated_capacity  \
# 0      INJ-001        사출기 1호기            사출기   A동 1라인           150.0
# 1      INJ-002        사출기 2호기            사출기   A동 1라인           150.0
#
#   installation_date  status           created_at           updated_at
# 0        2020-03-15  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00
# 1        2021-06-20  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00

# %%
# 장비 id 컬럼만 가져오기

# %%
df.head(2)
# Out:
#   equipment_id equipment_name equipment_type location  rated_capacity  \
# 0      INJ-001        사출기 1호기            사출기   A동 1라인           150.0
# 1      INJ-002        사출기 2호기            사출기   A동 1라인           150.0
#
#   installation_date  status           created_at           updated_at
# 0        2020-03-15  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00
# 1        2021-06-20  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00

# %%
df['equipment_id']
# Out:
# 0      INJ-001
# 1      INJ-002
# 2    PRESS-001
# 3    PRESS-002
# 4      ASM-001
# Name: equipment_id, dtype: object

# %%
df_production.head(2)
# Out:
#    production_id equipment_id product_code production_date  \
# 0              1      INJ-001     BUMPER-A      2024-01-01
# 1              2      INJ-001     BUMPER-A      2024-01-01
#
#             start_time             end_time  target_quantity  actual_quantity  \
# 0  2024-01-01 08:14:00  2024-01-01 09:53:32               97               81
# 1  2024-01-01 21:02:00  2024-01-01 22:33:43               83               78
#
#    good_quantity  defect_quantity  cycle_time   work_order_no  \
# 0             77                4       73.73  WO202401019935
# 1             72                6       70.56  WO202401012535
#
#              lot_no operator_id  shift           created_at  \
# 0  LOT2024010100101       OP003    DAY  2026-01-30 00:42:48
# 1  LOT2024010100110       OP006  NIGHT  2026-01-30 00:42:48
#
#             updated_at
# 0  2026-01-30 00:42:48
# 1  2026-01-30 00:42:48

# %%
df_production.columns
# Out:
# Index(['production_id', 'equipment_id', 'product_code', 'production_date',
#        'start_time', 'end_time', 'target_quantity', 'actual_quantity',
#        'good_quantity', 'defect_quantity', 'cycle_time', 'work_order_no',
#        'lot_no', 'operator_id', 'shift', 'created_at', 'updated_at'],
#       dtype='object')

# %%
df_production.head(2)
# Out:
#    production_id equipment_id product_code production_date  \
# 0              1      INJ-001     BUMPER-A      2024-01-01
# 1              2      INJ-001     BUMPER-A      2024-01-01
#
#             start_time             end_time  target_quantity  actual_quantity  \
# 0  2024-01-01 08:14:00  2024-01-01 09:53:32               97               81
# 1  2024-01-01 21:02:00  2024-01-01 22:33:43               83               78
#
#    good_quantity  defect_quantity  cycle_time   work_order_no  \
# 0             77                4       73.73  WO202401019935
# 1             72                6       70.56  WO202401012535
#
#              lot_no operator_id  shift           created_at  \
# 0  LOT2024010100101       OP003    DAY  2026-01-30 00:42:48
# 1  LOT2024010100110       OP006  NIGHT  2026-01-30 00:42:48
#
#             updated_at
# 0  2026-01-30 00:42:48
# 1  2026-01-30 00:42:48

# %%
df_production.loc[0,:]
# Out:
# production_id                        1
# equipment_id                   INJ-001
# product_code                  BUMPER-A
# production_date             2024-01-01
# start_time         2024-01-01 08:14:00
# end_time           2024-01-01 09:53:32
# target_quantity                     97
# actual_quantity                     81
# good_quantity                       77
# defect_quantity                      4
# cycle_time                       73.73
# work_order_no           WO202401019935
# lot_no                LOT2024010100101
# operator_id                      OP003
# shift                              DAY
# created_at         2026-01-30 00:42:48
# updated_at         2026-01-30 00:42:48
# Name: 0, dtype: object

# %%
df_production.head(2)
# Out:
#    production_id equipment_id product_code production_date  \
# 0              1      INJ-001     BUMPER-A      2024-01-01
# 1              2      INJ-001     BUMPER-A      2024-01-01
#
#             start_time             end_time  target_quantity  actual_quantity  \
# 0  2024-01-01 08:14:00  2024-01-01 09:53:32               97               81
# 1  2024-01-01 21:02:00  2024-01-01 22:33:43               83               78
#
#    good_quantity  defect_quantity  cycle_time   work_order_no  \
# 0             77                4       73.73  WO202401019935
# 1             72                6       70.56  WO202401012535
#
#              lot_no operator_id  shift           created_at  \
# 0  LOT2024010100101       OP003    DAY  2026-01-30 00:42:48
# 1  LOT2024010100110       OP006  NIGHT  2026-01-30 00:42:48
#
#             updated_at
# 0  2026-01-30 00:42:48
# 1  2026-01-30 00:42:48

# %%
df_production.loc[1:11,]
# Out:
#     production_id equipment_id product_code production_date  \
# 1               2      INJ-001     BUMPER-A      2024-01-01
# 2               3      INJ-002     BUMPER-A      2024-01-01
# 3               4      INJ-002       DASH-C      2024-01-01
# 4               5      INJ-002       DOOR-B      2024-01-01
# 5               6      INJ-002     BUMPER-A      2024-01-01
# 6               7    PRESS-001       DASH-C      2024-01-01
# 7               8    PRESS-001       DASH-C      2024-01-01
# 8               9    PRESS-001       DOOR-B      2024-01-01
# 9              10    PRESS-001       DOOR-B      2024-01-01
# 10             11    PRESS-002       DOOR-B      2024-01-01
# 11             12    PRESS-002       DASH-C      2024-01-01
#
#              start_time             end_time  target_quantity  \
# 1   2024-01-01 21:02:00  2024-01-01 22:33:43               83
# 2   2024-01-01 10:12:00  2024-01-01 13:16:28              149
# ...

# %%
df_production
# Out:
#       production_id equipment_id product_code production_date  \
# 0                 1      INJ-001     BUMPER-A      2024-01-01
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 2                 3      INJ-002     BUMPER-A      2024-01-01
# 3                 4      INJ-002       DASH-C      2024-01-01
# 4                 5      INJ-002       DOOR-B      2024-01-01
# ...             ...          ...          ...             ...
# 1867           1868    PRESS-002     BUMPER-A      2024-03-31
# 1868           1869    PRESS-002       DASH-C      2024-03-31
# 1869           1870    PRESS-002     BUMPER-A      2024-03-31
# 1870           1871      ASM-001     BUMPER-A      2024-03-31
# 1871           1872      ASM-001       DOOR-B      2024-03-31
#
#                start_time             end_time  target_quantity  \
# 0     2024-01-01 08:14:00  2024-01-01 09:53:32               97
# 1     2024-01-01 21:02:00  2024-01-01 22:33:43               83
# ...

# %%
df_production.loc[1:6,'equipment_id':'start_time']
# Out:
#   equipment_id product_code production_date           start_time
# 1      INJ-001     BUMPER-A      2024-01-01  2024-01-01 21:02:00
# 2      INJ-002     BUMPER-A      2024-01-01  2024-01-01 10:12:00
# 3      INJ-002       DASH-C      2024-01-01  2024-01-01 12:48:00
# 4      INJ-002       DOOR-B      2024-01-01  2024-01-01 20:48:00
# 5      INJ-002     BUMPER-A      2024-01-01  2024-01-02 00:22:00
# 6    PRESS-001       DASH-C      2024-01-01  2024-01-01 10:07:00

# %%
#조건 필터링

# %%
# 생산 데이터에서 설비아이디가 INJ-001 인 데이터만 가져오세요

# %%
# 이 데이터는 몇건인가?

# %%
df_production.head(2)
# Out:
#    production_id equipment_id product_code production_date  \
# 0              1      INJ-001     BUMPER-A      2024-01-01
# 1              2      INJ-001     BUMPER-A      2024-01-01
#
#             start_time             end_time  target_quantity  actual_quantity  \
# 0  2024-01-01 08:14:00  2024-01-01 09:53:32               97               81
# 1  2024-01-01 21:02:00  2024-01-01 22:33:43               83               78
#
#    good_quantity  defect_quantity  cycle_time   work_order_no  \
# 0             77                4       73.73  WO202401019935
# 1             72                6       70.56  WO202401012535
#
#              lot_no operator_id  shift           created_at  \
# 0  LOT2024010100101       OP003    DAY  2026-01-30 00:42:48
# 1  LOT2024010100110       OP006  NIGHT  2026-01-30 00:42:48
#
#             updated_at
# 0  2026-01-30 00:42:48
# 1  2026-01-30 00:42:48

# %%
df_production[df_production['equipment_id']=='INJ-001'] # boolean으로 인덱싱해서 적용된 데이터만 가져오는 법
# Out:
#       production_id equipment_id product_code production_date  \
# 0                 1      INJ-001     BUMPER-A      2024-01-01
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 20               21      INJ-001       DASH-C      2024-01-02
# 21               22      INJ-001       DOOR-B      2024-01-02
# 22               23      INJ-001     BUMPER-A      2024-01-02
# ...             ...          ...          ...             ...
# 1813           1814      INJ-001       DASH-C      2024-03-29
# 1834           1835      INJ-001     BUMPER-A      2024-03-30
# 1835           1836      INJ-001       DOOR-B      2024-03-30
# 1854           1855      INJ-001       DASH-C      2024-03-31
# 1855           1856      INJ-001     BUMPER-A      2024-03-31
#
#                start_time             end_time  target_quantity  \
# 0     2024-01-01 08:14:00  2024-01-01 09:53:32               97
# 1     2024-01-01 21:02:00  2024-01-01 22:33:43               83
# ...

# %%
df_production.loc[df_production['equipment_id']=='INJ-001',] #loc로 가져오는 법
# Out:
#       production_id equipment_id product_code production_date  \
# 0                 1      INJ-001     BUMPER-A      2024-01-01
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 20               21      INJ-001       DASH-C      2024-01-02
# 21               22      INJ-001       DOOR-B      2024-01-02
# 22               23      INJ-001     BUMPER-A      2024-01-02
# ...             ...          ...          ...             ...
# 1813           1814      INJ-001       DASH-C      2024-03-29
# 1834           1835      INJ-001     BUMPER-A      2024-03-30
# 1835           1836      INJ-001       DOOR-B      2024-03-30
# 1854           1855      INJ-001       DASH-C      2024-03-31
# 1855           1856      INJ-001     BUMPER-A      2024-03-31
#
#                start_time             end_time  target_quantity  \
# 0     2024-01-01 08:14:00  2024-01-01 09:53:32               97
# 1     2024-01-01 21:02:00  2024-01-01 22:33:43               83
# ...

# %%
df_production.head(2)
# Out:
#    production_id equipment_id product_code production_date  \
# 0              1      INJ-001     BUMPER-A      2024-01-01
# 1              2      INJ-001     BUMPER-A      2024-01-01
#
#             start_time             end_time  target_quantity  actual_quantity  \
# 0  2024-01-01 08:14:00  2024-01-01 09:53:32               97               81
# 1  2024-01-01 21:02:00  2024-01-01 22:33:43               83               78
#
#    good_quantity  defect_quantity  cycle_time   work_order_no  \
# 0             77                4       73.73  WO202401019935
# 1             72                6       70.56  WO202401012535
#
#              lot_no operator_id  shift           created_at  \
# 0  LOT2024010100101       OP003    DAY  2026-01-30 00:42:48
# 1  LOT2024010100110       OP006  NIGHT  2026-01-30 00:42:48
#
#             updated_at
# 0  2026-01-30 00:42:48
# 1  2026-01-30 00:42:48

# %%
#설비가 INJ-001이면서 불량이 5개 이상인 데이터만 가져오자.

# %%
df_production[(df_production['equipment_id']=='INJ-001') & (df_production['defect_quantity']>=5)]
# Out:
#       production_id equipment_id product_code production_date  \
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 20               21      INJ-001       DASH-C      2024-01-02
# 21               22      INJ-001       DOOR-B      2024-01-02
# 22               23      INJ-001     BUMPER-A      2024-01-02
# 23               24      INJ-001       DASH-C      2024-01-02
# ...             ...          ...          ...             ...
# 1813           1814      INJ-001       DASH-C      2024-03-29
# 1834           1835      INJ-001     BUMPER-A      2024-03-30
# 1835           1836      INJ-001       DOOR-B      2024-03-30
# 1854           1855      INJ-001       DASH-C      2024-03-31
# 1855           1856      INJ-001     BUMPER-A      2024-03-31
#
#                start_time             end_time  target_quantity  \
# 1     2024-01-01 21:02:00  2024-01-01 22:33:43               83
# 20    2024-01-02 08:18:00  2024-01-02 11:25:54              135
# ...

# %%
df_production[(df_production['actual_quantity']>=100) | (df_production['defect_quantity']>=5)]
# Out:
#       production_id equipment_id product_code production_date  \
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 2                 3      INJ-002     BUMPER-A      2024-01-01
# 4                 5      INJ-002       DOOR-B      2024-01-01
# 5                 6      INJ-002     BUMPER-A      2024-01-01
# 6                 7    PRESS-001       DASH-C      2024-01-01
# ...             ...          ...          ...             ...
# 1867           1868    PRESS-002     BUMPER-A      2024-03-31
# 1868           1869    PRESS-002       DASH-C      2024-03-31
# 1869           1870    PRESS-002     BUMPER-A      2024-03-31
# 1870           1871      ASM-001     BUMPER-A      2024-03-31
# 1871           1872      ASM-001       DOOR-B      2024-03-31
#
#                start_time             end_time  target_quantity  \
# 1     2024-01-01 21:02:00  2024-01-01 22:33:43               83
# 2     2024-01-01 10:12:00  2024-01-01 13:16:28              149
# ...

# %%
df_production.loc[(df_production['actual_quantity']>=100) | (df_production['defect_quantity']>=5),'actual_quantity':'good_quantity']
# Out:
#       actual_quantity  good_quantity
# 1                  78             72
# 2                 135            132
# 4                 129            122
# 5                 130            123
# 6                 106            102
# ...               ...            ...
# 1867              144            119
# 1868              130            109
# 1869               80             66
# 1870              121            101
# 1871               90             74
#
# [1731 rows x 2 columns]

# %%
df_q= pd.read_csv('./data/07_quality_inspection.csv')

# %%
df_q['result'] .unique()  #중복제거하고 특정값만 보여줌
# Out:
# array(['PASS', 'FAIL'], dtype=object)

# %%
df_q[df_q['result']=='FAIL']
# Out:
#        inspection_id  production_id equipment_id product_code  \
# 7                  8              1      INJ-001     BUMPER-A
# 8                  9              1      INJ-001     BUMPER-A
# 9                 10              1      INJ-001     BUMPER-A
# 10                11              1      INJ-001     BUMPER-A
# 18                19              2      INJ-001     BUMPER-A
# ...              ...            ...          ...          ...
# 37412          37413           1872      ASM-001       DOOR-B
# 37413          37414           1872      ASM-001       DOOR-B
# 37414          37415           1872      ASM-001       DOOR-B
# 37415          37416           1872      ASM-001       DOOR-B
# 37416          37417           1872      ASM-001       DOOR-B
#
#            inspection_time inspection_type result defect_code  \
# 7      2024-01-01 08:26:47           FINAL   FAIL        D002
# 8      2024-01-01 09:30:37           FINAL   FAIL        D002
# ...

# %%
#평군 생산량
#평균 양품 갯수
# 평균 불량 갯수
# 평균 불량률

# %%
df_q.head()
# Out:
#    inspection_id  production_id equipment_id product_code  \
# 0              1              1      INJ-001     BUMPER-A
# 1              2              1      INJ-001     BUMPER-A
# 2              3              1      INJ-001     BUMPER-A
# 3              4              1      INJ-001     BUMPER-A
# 4              5              1      INJ-001     BUMPER-A
#
#        inspection_time inspection_type result defect_code  measurement_value  \
# 0  2024-01-01 09:41:18           FINAL   PASS          \N           300.8279
# 1  2024-01-01 08:17:24           FINAL   PASS          \N           299.7696
# 2  2024-01-01 08:47:26           FINAL   PASS          \N           301.0795
# 3  2024-01-01 08:33:03           FINAL   PASS          \N           302.5384
# 4  2024-01-01 09:46:23           FINAL   PASS          \N           299.6097
#
#   measurement_unit inspector_id            lot_no  sample_size  notes  \
# 0               mm        OP007  LOT2024010100101            1    NaN
# ...

# %%
#inj-001이면서 bumper-a

# %%
df_target=df_production.loc[(df_production['equipment_id']=='INJ-001') & (df_production['product_code'] == 'BUMPER-A')]

# %%
df_target
# Out:
#       production_id equipment_id product_code production_date  \
# 0                 1      INJ-001     BUMPER-A      2024-01-01
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 22               23      INJ-001     BUMPER-A      2024-01-02
# 59               60      INJ-001     BUMPER-A      2024-01-04
# 60               61      INJ-001     BUMPER-A      2024-01-04
# ...             ...          ...          ...             ...
# 1792           1793      INJ-001     BUMPER-A      2024-03-28
# 1793           1794      INJ-001     BUMPER-A      2024-03-28
# 1812           1813      INJ-001     BUMPER-A      2024-03-29
# 1834           1835      INJ-001     BUMPER-A      2024-03-30
# 1855           1856      INJ-001     BUMPER-A      2024-03-31
#
#                start_time             end_time  target_quantity  \
# 0     2024-01-01 08:14:00  2024-01-01 09:53:32               97
# 1     2024-01-01 21:02:00  2024-01-01 22:33:43               83
# ...

# %%
f" 평균 생산량 : {df_target['actual_quantity'].mean():.1f}개"
# Out:
# ' 평균 생산량 : 104.4개'

# %%
## 평균 불량률 !!!

# %%
# 불량 갯수 / 전체 갯수 *100

# %%
df_target['defect_quantity'].sum()/df_target['actual_quantity'].sum() *100
# Out:
# np.float64(11.401731442254558)

# %%
###########실습##########3

# %%
#1번

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', 20)

# %%
equipment_df=pd.read_csv('./data/01_equipment.csv')

# %%
equipment_df.head(3)
# Out:
#   equipment_id equipment_name equipment_type location  rated_capacity  \
# 0      INJ-001        사출기 1호기            사출기   A동 1라인           150.0
# 1      INJ-002        사출기 2호기            사출기   A동 1라인           150.0
# 2    PRESS-001        프레스 1호기            프레스   A동 2라인           200.0
#
#   installation_date  status           created_at           updated_at
# 0        2020-03-15  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00
# 1        2021-06-20  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00
# 2        2019-05-10  ACTIVE  2024-01-01 00:00:00  2024-01-01 00:00:00

# %%
equipment_df.shape
# Out:
# (5, 9)

# %%
equipment_df.columns
# Out:
# Index(['equipment_id', 'equipment_name', 'equipment_type', 'location',
#        'rated_capacity', 'installation_date', 'status', 'created_at',
#        'updated_at'],
#       dtype='object')

# %%
#2번

# %%
equipment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   equipment_id       5 non-null      object
#  1   equipment_name     5 non-null      object
#  2   equipment_type     5 non-null      object
#  3   location           5 non-null      object
#  4   rated_capacity     5 non-null      float64
#  5   installation_date  5 non-null      object
#  6   status             5 non-null      object
#  7   created_at         5 non-null      object
#  8   updated_at         5 non-null      object
# dtypes: float64(1), object(8)
# memory usage: 488.0+ bytes

# %%
equipment_df.describe()
# Out:
#        rated_capacity
# count        5.000000
# mean       160.000000
# std         41.833001
# min        100.000000
# 25%        150.000000
# 50%        150.000000
# 75%        200.000000
# max        200.000000

# %%
##결측치 있는거 rated_capacity

# %%
#3번

# %%
production_df=pd.read_csv('./data/05_production.csv')

# %%
len(production_df)
# Out:
# 1872

# %%
production_df.head(10)
# Out:
#    production_id equipment_id product_code production_date  \
# 0              1      INJ-001     BUMPER-A      2024-01-01
# 1              2      INJ-001     BUMPER-A      2024-01-01
# 2              3      INJ-002     BUMPER-A      2024-01-01
# 3              4      INJ-002       DASH-C      2024-01-01
# 4              5      INJ-002       DOOR-B      2024-01-01
# 5              6      INJ-002     BUMPER-A      2024-01-01
# 6              7    PRESS-001       DASH-C      2024-01-01
# 7              8    PRESS-001       DASH-C      2024-01-01
# 8              9    PRESS-001       DOOR-B      2024-01-01
# 9             10    PRESS-001       DOOR-B      2024-01-01
#
#             start_time             end_time  target_quantity  actual_quantity  \
# 0  2024-01-01 08:14:00  2024-01-01 09:53:32               97               81
# 1  2024-01-01 21:02:00  2024-01-01 22:33:43               83               78
# 2  2024-01-01 10:12:00  2024-01-01 13:16:28              149              135
# ...

# %%
production_df.columns
# Out:
# Index(['production_id', 'equipment_id', 'product_code', 'production_date',
#        'start_time', 'end_time', 'target_quantity', 'actual_quantity',
#        'good_quantity', 'defect_quantity', 'cycle_time', 'work_order_no',
#        'lot_no', 'operator_id', 'shift', 'created_at', 'updated_at'],
#       dtype='object')

# %%
new_df=production_df[['equipment_id','product_code','actual_quantity','good_quantity','defect_quantity']]

# %%
new_df.head(5)
# Out:
#   equipment_id product_code  actual_quantity  good_quantity  defect_quantity
# 0      INJ-001     BUMPER-A               81             77                4
# 1      INJ-001     BUMPER-A               78             72                6
# 2      INJ-002     BUMPER-A              135            132                3
# 3      INJ-002       DASH-C               92             90                2
# 4      INJ-002       DOOR-B              129            122                7

# %%
production_df.loc[:,['equipment_id','product_code','actual_quantity','good_quantity','defect_quantity']]
# Out:
#      equipment_id product_code  actual_quantity  good_quantity  \
# 0         INJ-001     BUMPER-A               81             77
# 1         INJ-001     BUMPER-A               78             72
# 2         INJ-002     BUMPER-A              135            132
# 3         INJ-002       DASH-C               92             90
# 4         INJ-002       DOOR-B              129            122
# ...           ...          ...              ...            ...
# 1867    PRESS-002     BUMPER-A              144            119
# 1868    PRESS-002       DASH-C              130            109
# 1869    PRESS-002     BUMPER-A               80             66
# 1870      ASM-001     BUMPER-A              121            101
# 1871      ASM-001       DOOR-B               90             74
#
#       defect_quantity
# 0                   4
# 1                   6
# 2                   3
# 3                   2
# 4                   7
# ...               ...
# 1867               25
# ...

# %%
#4번 문제

# %%
production_df.iloc[:10,]
# Out:
#    production_id equipment_id product_code production_date  \
# 0              1      INJ-001     BUMPER-A      2024-01-01
# 1              2      INJ-001     BUMPER-A      2024-01-01
# 2              3      INJ-002     BUMPER-A      2024-01-01
# 3              4      INJ-002       DASH-C      2024-01-01
# 4              5      INJ-002       DOOR-B      2024-01-01
# 5              6      INJ-002     BUMPER-A      2024-01-01
# 6              7    PRESS-001       DASH-C      2024-01-01
# 7              8    PRESS-001       DASH-C      2024-01-01
# 8              9    PRESS-001       DOOR-B      2024-01-01
# 9             10    PRESS-001       DOOR-B      2024-01-01
#
#             start_time             end_time  target_quantity  actual_quantity  \
# 0  2024-01-01 08:14:00  2024-01-01 09:53:32               97               81
# 1  2024-01-01 21:02:00  2024-01-01 22:33:43               83               78
# 2  2024-01-01 10:12:00  2024-01-01 13:16:28              149              135
# ...

# %%
production_df.iloc[19:29,]
# Out:
#     production_id equipment_id product_code production_date  \
# 19             20      ASM-001       DOOR-B      2024-01-01
# 20             21      INJ-001       DASH-C      2024-01-02
# 21             22      INJ-001       DOOR-B      2024-01-02
# 22             23      INJ-001     BUMPER-A      2024-01-02
# 23             24      INJ-001       DASH-C      2024-01-02
# 24             25      INJ-002       DASH-C      2024-01-02
# 25             26      INJ-002       DOOR-B      2024-01-02
# 26             27      INJ-002       DASH-C      2024-01-02
# 27             28      INJ-002     BUMPER-A      2024-01-02
# 28             29    PRESS-001     BUMPER-A      2024-01-02
#
#              start_time             end_time  target_quantity  \
# 19  2024-01-02 00:43:00  2024-01-02 02:22:49               94
# 20  2024-01-02 08:18:00  2024-01-02 11:25:54              135
# 21  2024-01-02 14:56:00  2024-01-02 16:44:06              113
# ...

# %%
production_df.iloc[0:4,1:6]
# Out:
#   equipment_id product_code production_date           start_time  \
# 0      INJ-001     BUMPER-A      2024-01-01  2024-01-01 08:14:00
# 1      INJ-001     BUMPER-A      2024-01-01  2024-01-01 21:02:00
# 2      INJ-002     BUMPER-A      2024-01-01  2024-01-01 10:12:00
# 3      INJ-002       DASH-C      2024-01-01  2024-01-01 12:48:00
#
#               end_time
# 0  2024-01-01 09:53:32
# 1  2024-01-01 22:33:43
# 2  2024-01-01 13:16:28
# 3  2024-01-01 15:16:31

# %%
#5번 문제

# %%
len(production_df[production_df['equipment_id']=='PRESS-001'])
# Out:
# 468

# %%
production_df[production_df['actual_quantity']>=100].head(10)
# Out:
#     production_id equipment_id product_code production_date  \
# 2               3      INJ-002     BUMPER-A      2024-01-01
# 4               5      INJ-002       DOOR-B      2024-01-01
# 5               6      INJ-002     BUMPER-A      2024-01-01
# 6               7    PRESS-001       DASH-C      2024-01-01
# 9              10    PRESS-001       DOOR-B      2024-01-01
# 11             12    PRESS-002       DASH-C      2024-01-01
# 13             14    PRESS-002       DOOR-B      2024-01-01
# 14             15    PRESS-002       DASH-C      2024-01-01
# 15             16    PRESS-002       DOOR-B      2024-01-01
# 18             19      ASM-001       DASH-C      2024-01-01
#
#              start_time             end_time  target_quantity  \
# 2   2024-01-01 10:12:00  2024-01-01 13:16:28              149
# 4   2024-01-01 20:48:00  2024-01-01 23:12:13              123
# 5   2024-01-02 00:22:00  2024-01-02 03:10:05              124
# ...

# %%
len(production_df[production_df['defect_quantity']==0])
# Out:
# 0

# %%
#6번

# %%
production_df[(production_df['equipment_id']=='INJ-001') & (production_df['defect_quantity']>=5)]
# Out:
#       production_id equipment_id product_code production_date  \
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 20               21      INJ-001       DASH-C      2024-01-02
# 21               22      INJ-001       DOOR-B      2024-01-02
# 22               23      INJ-001     BUMPER-A      2024-01-02
# 23               24      INJ-001       DASH-C      2024-01-02
# ...             ...          ...          ...             ...
# 1813           1814      INJ-001       DASH-C      2024-03-29
# 1834           1835      INJ-001     BUMPER-A      2024-03-30
# 1835           1836      INJ-001       DOOR-B      2024-03-30
# 1854           1855      INJ-001       DASH-C      2024-03-31
# 1855           1856      INJ-001     BUMPER-A      2024-03-31
#
#                start_time             end_time  target_quantity  \
# 1     2024-01-01 21:02:00  2024-01-01 22:33:43               83
# 20    2024-01-02 08:18:00  2024-01-02 11:25:54              135
# ...

# %%
production_df[(production_df['actual_quantity']<50) | (production_df['actual_quantity']>150)]
# Out:
#       production_id equipment_id product_code production_date  \
# 26               27      INJ-002       DASH-C      2024-01-02
# 44               45      INJ-002       DOOR-B      2024-01-03
# 106             107      INJ-002     BUMPER-A      2024-01-06
# 126             127      INJ-002       DASH-C      2024-01-07
# 130             131      INJ-002     BUMPER-A      2024-01-07
# 172             173      INJ-002       DASH-C      2024-01-09
# 194             195      INJ-002     BUMPER-A      2024-01-10
# 214             215      INJ-002       DASH-C      2024-01-11
# 257             258      INJ-002     BUMPER-A      2024-01-13
# 312             313      INJ-002       DOOR-B      2024-01-16
# 351             352      INJ-002       DOOR-B      2024-01-18
# 374             375      INJ-002     BUMPER-A      2024-01-19
# 434             435      INJ-002     BUMPER-A      2024-01-22
# 489             490      INJ-002       DASH-C      2024-01-25
# ...

# %%
len(production_df[(production_df['product_code']=='BUMPER-A') & (production_df['good_quantity']>=100)])
# Out:
# 299

# %%
#7번

# %%
production_df[production_df['equipment_id']=='INJ-001']
# Out:
#       production_id equipment_id product_code production_date  \
# 0                 1      INJ-001     BUMPER-A      2024-01-01
# 1                 2      INJ-001     BUMPER-A      2024-01-01
# 20               21      INJ-001       DASH-C      2024-01-02
# 21               22      INJ-001       DOOR-B      2024-01-02
# 22               23      INJ-001     BUMPER-A      2024-01-02
# ...             ...          ...          ...             ...
# 1813           1814      INJ-001       DASH-C      2024-03-29
# 1834           1835      INJ-001     BUMPER-A      2024-03-30
# 1835           1836      INJ-001       DOOR-B      2024-03-30
# 1854           1855      INJ-001       DASH-C      2024-03-31
# 1855           1856      INJ-001     BUMPER-A      2024-03-31
#
#                start_time             end_time  target_quantity  \
# 0     2024-01-01 08:14:00  2024-01-01 09:53:32               97
# 1     2024-01-01 21:02:00  2024-01-01 22:33:43               83
# ...

# %%
production_df[(production_df['actual_quantity']<=120) &  (production_df['actual_quantity'] >=80)].head(5)
# Out:
#     production_id equipment_id product_code production_date  \
# 0               1      INJ-001     BUMPER-A      2024-01-01
# 3               4      INJ-002       DASH-C      2024-01-01
# 6               7    PRESS-001       DASH-C      2024-01-01
# 8               9    PRESS-001       DOOR-B      2024-01-01
# 11             12    PRESS-002       DASH-C      2024-01-01
#
#              start_time             end_time  target_quantity  \
# 0   2024-01-01 08:14:00  2024-01-01 09:53:32               97
# 3   2024-01-01 12:48:00  2024-01-01 15:16:31              100
# 6   2024-01-01 10:07:00  2024-01-01 12:48:06              128
# 8   2024-01-01 20:55:00  2024-01-01 22:27:01               92
# 11  2024-01-01 12:29:00  2024-01-01 14:47:43              128
#
#     actual_quantity  good_quantity  defect_quantity  cycle_time  \
# 0                81             77                4       73.73
# 3                92             90                2       96.87
# ...

# %%
df_1=pd.read_csv('./data/07_quality_inspection.csv')

# %%
len(df_1)
# Out:
# 37417

# %%
df_1[df_1['result']=='FAIL'].head(2)
# Out:
#    inspection_id  production_id equipment_id product_code  \
# 7              8              1      INJ-001     BUMPER-A
# 8              9              1      INJ-001     BUMPER-A
#
#        inspection_time inspection_type result defect_code  measurement_value  \
# 7  2024-01-01 08:26:47           FINAL   FAIL        D002           305.2058
# 8  2024-01-01 09:30:37           FINAL   FAIL        D002           314.6991
#
#   measurement_unit inspector_id            lot_no  sample_size  notes  \
# 7               mm        OP007  LOT2024010100101            1    NaN
# 8               mm        OP008  LOT2024010100101            1    NaN
#
#             created_at
# 7  2026-01-30 01:24:59
# 8  2026-01-30 01:24:59

# %%
len(df_1[df_1['result']=='FAIL']) /len(df_1) *100
# Out:
# 55.79282144479782

# %%
df_1[(df_1['measurement_value']<300 )| (df_1['measurement_value']>310 )]
# Out:
#        inspection_id  production_id equipment_id product_code  \
# 1                  2              1      INJ-001     BUMPER-A
# 4                  5              1      INJ-001     BUMPER-A
# 5                  6              1      INJ-001     BUMPER-A
# 8                  9              1      INJ-001     BUMPER-A
# 9                 10              1      INJ-001     BUMPER-A
# ...              ...            ...          ...          ...
# 37412          37413           1872      ASM-001       DOOR-B
# 37413          37414           1872      ASM-001       DOOR-B
# 37414          37415           1872      ASM-001       DOOR-B
# 37415          37416           1872      ASM-001       DOOR-B
# 37416          37417           1872      ASM-001       DOOR-B
#
#            inspection_time inspection_type result defect_code  \
# 1      2024-01-01 08:17:24           FINAL   PASS          \N
# 4      2024-01-01 09:46:23           FINAL   PASS          \N
# ...
